# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('time_series_19-covid-Deaths.csv')

# %%
print(data)
# Out:
#     Province/State  Country/Region      Lat  ...  3/8/20  3/9/20  3/10/20
# 0            Anhui  Mainland China  31.8257  ...       6       6        6
# 1          Beijing  Mainland China  40.1824  ...       8       8        8
# 2        Chongqing  Mainland China  30.0572  ...       6       6        6
# 3           Fujian  Mainland China  26.0789  ...       1       1        1
# 4            Gansu  Mainland China  36.0611  ...       2       2        2
# ..             ...             ...      ...  ...     ...     ...      ...
# 342       Dane, WI              US  43.0186  ...       0       0        0
# 343     Pierce, WI              US  44.7509  ...       0       0        0
# 344   Cuyahoga, OH              US  41.4339  ...       0       0        0
# 345      Weber, UT              US  41.2603  ...       0       0        0
# 346     Wilton, CT              US  41.1954  ...       0       0        0
#
# [347 rows x 53 columns]

# %%
data.describe()
# Out:
#               Lat        Long  ...       3/9/20      3/10/20
# count  347.000000  347.000000  ...   347.000000   347.000000
# mean    34.147598  -31.658554  ...    11.492795    12.363112
# std     17.065602   84.577987  ...   163.755411   166.413270
# min    -41.454500 -157.858400  ...     0.000000     0.000000
# 25%     31.742200  -92.721500  ...     0.000000     0.000000
# 50%     38.502500  -74.297300  ...     0.000000     0.000000
# 75%     42.271000   25.249700  ...     0.000000     0.000000
# max     64.963100  174.886000  ...  3008.000000  3024.000000
#
# [8 rows x 51 columns]

# %%
data.drop(['Lat','Long','Country/Region','Province/State'],axis=1,inplace=True)

# %%
data.describe()
# Out:
#           1/22/20     1/23/20  ...       3/9/20      3/10/20
# count  347.000000  347.000000  ...   347.000000   347.000000
# mean     0.048991    0.051873  ...    11.492795    12.363112
# std      0.912608    0.914030  ...   163.755411   166.413270
# min      0.000000    0.000000  ...     0.000000     0.000000
# 25%      0.000000    0.000000  ...     0.000000     0.000000
# 50%      0.000000    0.000000  ...     0.000000     0.000000
# 75%      0.000000    0.000000  ...     0.000000     0.000000
# max     17.000000   17.000000  ...  3008.000000  3024.000000
#
# [8 rows x 49 columns]

# %%
data=data.sum(axis=0,skipna=True)

# %%
data
# Out:
# 1/22/20      17
# 1/23/20      18
# 1/24/20      26
# 1/25/20      42
# 1/26/20      56
# 1/27/20      82
# 1/28/20     131
# 1/29/20     133
# 1/30/20     171
# 1/31/20     213
# 2/1/20      259
# 2/2/20      362
# 2/3/20      426
# 2/4/20      492
# 2/5/20      564
# 2/6/20      634
# 2/7/20      719
# 2/8/20      806
# 2/9/20      906
# 2/10/20    1013
# 2/11/20    1113
# 2/12/20    1118
# 2/13/20    1371
# 2/14/20    1523
# 2/15/20    1666
# 2/16/20    1770
# 2/17/20    1868
# 2/18/20    2007
# 2/19/20    2122
# 2/20/20    2247
# 2/21/20    2251
# 2/22/20    2458
# 2/23/20    2469
# 2/24/20    2629
# 2/25/20    2708
# 2/26/20    2770
# 2/27/20    2814
# 2/28/20    2872
# 2/29/20    2941
# 3/1/20     2996
# 3/2/20     3085
# 3/3/20     3160
# 3/4/20     3254
# 3/5/20     3348
# 3/6/20     3460
# 3/7/20     3558
# 3/8/20     3802
# 3/9/20     3988
# 3/10/20    4290
# dtype: int64

# %% [markdown]
# This plot shows us the number of death from 22/january/2020 to 10/march/2020

# %%
plt.plot(data)
