# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
#importing required library

# %%
df=pd.read_csv('confirmed_global.csv')

# %%
df.head()
# Out:
#   Province/State Country/Region      Lat  ...  4/7/20  4/8/20  4/9/20
# 0            NaN    Afghanistan  33.0000  ...     423     444     484
# 1            NaN        Albania  41.1533  ...     383     400     409
# 2            NaN        Algeria  28.0339  ...    1468    1572    1666
# 3            NaN        Andorra  42.5063  ...     545     564     583
# 4            NaN         Angola -11.2027  ...      17      19      19
#
# [5 rows x 83 columns]

# %%
df.drop(columns=['Province/State','Lat','Long'],inplace=True)

# %%
df.head()
# Out:
#   Country/Region  1/22/20  1/23/20  1/24/20  ...  4/6/20  4/7/20  4/8/20  4/9/20
# 0    Afghanistan        0        0        0  ...     367     423     444     484
# 1        Albania        0        0        0  ...     377     383     400     409
# 2        Algeria        0        0        0  ...    1423    1468    1572    1666
# 3        Andorra        0        0        0  ...     525     545     564     583
# 4         Angola        0        0        0  ...      16      17      19      19
#
# [5 rows x 80 columns]

# %%
print(len(df.axes[1]),len(df.axes[0]))
# Out:
# 80 263

# %%
df=df.groupby(['Country/Region']).sum().reset_index()

# %%
df.head()
# Out:
#   Country/Region  1/22/20  1/23/20  1/24/20  ...  4/6/20  4/7/20  4/8/20  4/9/20
# 0    Afghanistan        0        0        0  ...     367     423     444     484
# 1        Albania        0        0        0  ...     377     383     400     409
# 2        Algeria        0        0        0  ...    1423    1468    1572    1666
# 3        Andorra        0        0        0  ...     525     545     564     583
# 4         Angola        0        0        0  ...      16      17      19      19
#
# [5 rows x 80 columns]

# %%
print(len(df.axes[1]),len(df.axes[0]))
#columns and rows after grouping the data according to country
# Out:
# 80 184

# %%
col=df.keys()
col
# Out:
# Index(['Country/Region', '1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20',
#        '1/27/20', '1/28/20', '1/29/20', '1/30/20', '1/31/20', '2/1/20',
#        '2/2/20', '2/3/20', '2/4/20', '2/5/20', '2/6/20', '2/7/20', '2/8/20',
#        '2/9/20', '2/10/20', '2/11/20', '2/12/20', '2/13/20', '2/14/20',
#        '2/15/20', '2/16/20', '2/17/20', '2/18/20', '2/19/20', '2/20/20',
#        '2/21/20', '2/22/20', '2/23/20', '2/24/20', '2/25/20', '2/26/20',
#        '2/27/20', '2/28/20', '2/29/20', '3/1/20', '3/2/20', '3/3/20', '3/4/20',
#        '3/5/20', '3/6/20', '3/7/20', '3/8/20', '3/9/20', '3/10/20', '3/11/20',
#        '3/12/20', '3/13/20', '3/14/20', '3/15/20', '3/16/20', '3/17/20',
#        '3/18/20', '3/19/20', '3/20/20', '3/21/20', '3/22/20', '3/23/20',
#        '3/24/20', '3/25/20', '3/26/20', '3/27/20', '3/28/20', '3/29/20',
#        '3/30/20', '3/31/20', '4/1/20', '4/2/20', '4/3/20', '4/4/20', '4/5/20',
#        '4/6/20', '4/7/20', '4/8/20', '4/9/20'],
# ...

# %%
df_cpy=df.loc[:,col[1]:col[-1]]

# %%
df_cpy.describe()
# Out:
#           1/22/20     1/23/20  ...         4/8/20         4/9/20
# count  184.000000  184.000000  ...     184.000000     184.000000
# mean     3.016304    3.554348  ...    8212.521739    8670.380435
# std     40.397002   47.399330  ...   37585.670545   39976.456300
# min      0.000000    0.000000  ...       1.000000       1.000000
# 25%      0.000000    0.000000  ...      30.000000      30.750000
# 50%      0.000000    0.000000  ...     350.000000     379.000000
# 75%      0.000000    0.000000  ...    2068.250000    2254.500000
# max    548.000000  643.000000  ...  429052.000000  461437.000000
#
# [8 rows x 79 columns]

# %%
dates=df_cpy.keys()
dates
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20', '2/1/20', '2/2/20',
#        '2/3/20', '2/4/20', '2/5/20', '2/6/20', '2/7/20', '2/8/20', '2/9/20',
#        '2/10/20', '2/11/20', '2/12/20', '2/13/20', '2/14/20', '2/15/20',
#        '2/16/20', '2/17/20', '2/18/20', '2/19/20', '2/20/20', '2/21/20',
#        '2/22/20', '2/23/20', '2/24/20', '2/25/20', '2/26/20', '2/27/20',
#        '2/28/20', '2/29/20', '3/1/20', '3/2/20', '3/3/20', '3/4/20', '3/5/20',
#        '3/6/20', '3/7/20', '3/8/20', '3/9/20', '3/10/20', '3/11/20', '3/12/20',
#        '3/13/20', '3/14/20', '3/15/20', '3/16/20', '3/17/20', '3/18/20',
#        '3/19/20', '3/20/20', '3/21/20', '3/22/20', '3/23/20', '3/24/20',
#        '3/25/20', '3/26/20', '3/27/20', '3/28/20', '3/29/20', '3/30/20',
#        '3/31/20', '4/1/20', '4/2/20', '4/3/20', '4/4/20', '4/5/20', '4/6/20',
#        '4/7/20', '4/8/20', '4/9/20'],
#       dtype='object')

# %%
l=[]
for i in dates:
  l.append(df1_cpy[i].sum())

# %%
l
# Out:
# [555,
#  654,
#  941,
#  1434,
#  2118,
#  2927,
#  5578,
#  6166,
#  8234,
#  9927,
#  12038,
#  16787,
#  19881,
#  23892,
#  27635,
#  30794,
#  34391,
#  37120,
#  40150,
#  42762,
#  44802,
#  45221,
#  60368,
#  66885,
#  69030,
#  71224,
#  73258,
#  75136,
#  75639,
#  76197,
#  76819,
#  78572,
#  78958,
#  79561,
#  80406,
#  81388,
#  82746,
#  84112,
#  86011,
#  88369,
#  90306,
#  92840,
#  95120,
#  97886,
#  101801,
#  105847,
#  109821,
#  113590,
#  118620,
#  125875,
#  128352,
#  145205,
#  156101,
#  167454,
#  181574,
#  197102,
#  214821,
#  242570,
#  272208,
#  304507,
#  336953,
#  378235,
#  418045,
#  467653,
#  529591,
#  593291,
#  660693,
#  720140,
#  782389,
#  857487,
#  932605,
#  1013466,
#  1095917,
#  1197408,
#  1272115,
#  1345101,
#  1426096,
#  1511104,
#  1595350]

# %%
plt.plot(dates,l)
